# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
O_dataset = pd.DataFrame([567,572,572,589,614,616,628,645,650,652,657,661,666,668,669,675,676,
                        686,694,698,706,706,708,711,714,716,722,728,729,729,730,732,735,737,737,
                        738,740,741,744,747,748,748,749,750,752,755,755,758,761,764,769,775,781,782,786,793,793,
                        795,798,799,800,800,811,812,814,814,815,818,819,821,821,826,829,841,842,843,850,875,879,897
                         ])

# %%
O_dataset.mean()
# Out:
# 0    743.0375
# dtype: float64

# %%
O_dataset.std()
# Out:
# 0    74.042657
# dtype: float64

# %%
S_dataset=O_dataset-O_dataset.mean()
S_dataset.head()
# Out:
#           0
# 0 -176.0375
# 1 -171.0375
# 2 -171.0375
# 3 -154.0375
# 4 -129.0375

# %%
S_dataset=S_dataset/S_dataset.std()
S_dataset.head()
# Out:
#           0
# 0 -2.377515
# 1 -2.309986
# 2 -2.309986
# 3 -2.080389
# 4 -1.742745

# %%
S_dataset.mean()
S_dataset
# Out:
#            0
# 0  -2.377515
# 1  -2.309986
# 2  -2.309986
# 3  -2.080389
# 4  -1.742745
# ..       ...
# 75  1.350066
# 76  1.444606
# 77  1.782250
# 78  1.836273
# 79  2.079376
#
# [80 rows x 1 columns]

# %%
S_dataset.std()
# Out:
# 0    1.0
# dtype: float64

# %% [markdown]
# # data generate

# %%
import random
data = np.round(np.random.randint(0,1000,960))*100
data
# Out:
# array([65900, 29600,  9500, 36300, 66800, 80500, 19500, 52600, 67900,
#        26800, 32200, 16000,  3600,  6100, 65300, 47500,  2900, 85100,
#        92400, 10900, 59800, 68700,   800, 69400, 38000, 96600, 57400,
#        99200, 35000, 11200, 79200, 41800,  9400, 19400, 10100,  2100,
#        47200, 17400, 23000, 31600, 89600, 42200, 17900, 10600, 57300,
#        51900, 52100, 49100, 77100, 74800, 25700, 45500, 40000, 87500,
#        70300, 33100, 43900, 19200, 90800, 62000,  6000, 55200,  3200,
#        48700, 65500, 63500, 35000, 81900, 54600, 67500,  9700, 65700,
#        60800, 80000, 17900, 55500, 92500, 23100, 10200, 50700, 47700,
#        29000, 55700,  4400, 50200, 54700, 40400, 96500, 18100, 11400,
#        31600, 72800,  2700, 34400, 16400,  8700, 74300, 47900, 66600,
#         8600,  1300, 27900, 31800, 56000, 61700,  7400, 19100, 70700,
#        97300, 64200, 66000, 87200, 46200, 19500, 70300, 36800,  5700,
# ...
