# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('data.csv')

# %%
data
# Out:
#        ID  Building  Year of sale  Month of sale Type of property  Property #  \
# 0    1030         1        2005.0           11.0        Apartment          30
# 1    1029         1        2005.0           10.0        Apartment          29
# 2    2002         2        2007.0            7.0        Apartment           2
# 3    2031         2        2007.0           12.0        Apartment          31
# 4    1049         1        2004.0           11.0        Apartment          49
# ..    ...       ...           ...            ...              ...         ...
# 262  5044         5           NaN            NaN        Apartment          44
# 263  5047         5           NaN            NaN        Apartment          47
# 264  5048         5           NaN            NaN        Apartment          48
# 265  5050         5           NaN            NaN        Apartment          50
# 266  5051         5           NaN            NaN        Apartment          51
#
# ...

# %%
data.columns
# Out:
# Index(['ID', 'Building', 'Year of sale', 'Month of sale', 'Type of property',
#        'Property #', 'Area (ft.)', 'Price', 'Status', 'Unnamed: 9',
#        'Customer ID', 'Entity', 'Name', 'Surname', 'Age at time of purchase',
#        'Interval', 'Y', 'M', 'D', 'Gender', 'Country', 'State', 'Purpose',
#        'Deal satisfaction', 'Mortgage', 'Source'],
#       dtype='object')

# %%
data['Gender'].fillna('Firm',inplace=True)

# %%
data
# Out:
#        ID  Building  Year of sale  Month of sale Type of property  Property #  \
# 0    1030         1        2005.0           11.0        Apartment          30
# 1    1029         1        2005.0           10.0        Apartment          29
# 2    2002         2        2007.0            7.0        Apartment           2
# 3    2031         2        2007.0           12.0        Apartment          31
# 4    1049         1        2004.0           11.0        Apartment          49
# ..    ...       ...           ...            ...              ...         ...
# 262  5044         5           NaN            NaN        Apartment          44
# 263  5047         5           NaN            NaN        Apartment          47
# 264  5048         5           NaN            NaN        Apartment          48
# 265  5050         5           NaN            NaN        Apartment          50
# 266  5051         5           NaN            NaN        Apartment          51
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 267 entries, 0 to 266
# Data columns (total 26 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       267 non-null    int64
#  1   Building                 267 non-null    int64
#  2   Year of sale             195 non-null    float64
#  3   Month of sale            195 non-null    float64
#  4   Type of property         267 non-null    object
#  5   Property #               267 non-null    int64
#  6   Area (ft.)               267 non-null    float64
#  7   Price                    267 non-null    object
#  8   Status                   195 non-null    object
#  9   Unnamed: 9               0 non-null      float64
#  10  Customer ID              195 non-null    object
#  11  Entity                   195 non-null    object
#  12  Name                     195 non-null    object
#  13  Surname                  195 non-null    object
# ...

# %%
frequency=data['Gender'].value_counts()
frequency
# Out:
# M       108
# Firm     89
# F        70
# Name: Gender, dtype: int64

# %%
plt.pie(frequency,autopct='%1.1f%%',labels=['male','firms','female'])
# Out:
# ([<matplotlib.patches.Wedge at 0x2a5c0d15400>,
# ...
#  [Text(0.3251140200774819, 1.0508572091150439, 'male'),
#   Text(-0.9918666046860226, -0.47560554928282894, 'firms'),
#   Text(0.7475120539900509, -0.8069855817420627, 'female')],
#  [Text(0.17733492004226284, 0.5731948413354784, '40.4%'),
#   Text(-0.5410181480105577, -0.25942120869972485, '33.3%'),
#   Text(0.40773384763093684, -0.4401739536774887, '26.2%')])

# %%
data['state'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'state'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-27327c24c066> in <module>
# ----> 1 data['state'].value_counts()
#
# ...
