# %%
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
df = pd.read_excel(r'C:\Users\R01-PC2\Desktop\set house data.xlsx')

# %%
df
# Out:
#        ID  Building  Year of sale  Month of sale Type of property  Property #  \
# 0    1030         1        2005.0           11.0        Apartment          30
# 1    1029         1        2005.0           10.0        Apartment          29
# 2    2002         2        2007.0            7.0        Apartment           2
# 3    2031         2        2007.0           12.0        Apartment          31
# 4    1049         1        2004.0           11.0        Apartment          49
# ..    ...       ...           ...            ...              ...         ...
# 191  1022         1        2005.0            7.0        Apartment          22
# 192  1028         1        2005.0            7.0        Apartment          28
# 193  1034         1        2005.0            7.0        Apartment          34
# 194  1037         1        2005.0            7.0        Apartment          37
# 195  1042         1        2005.0            7.0        Apartment          42
#
# ...

# %%
df['Gender'] = df['Gender'].replace(np.nan, "firms")

# %%
df
# Out:
#        ID  Building  Year of sale  Month of sale Type of property  Property #  \
# 0    1030         1        2005.0           11.0        Apartment          30
# 1    1029         1        2005.0           10.0        Apartment          29
# 2    2002         2        2007.0            7.0        Apartment           2
# 3    2031         2        2007.0           12.0        Apartment          31
# 4    1049         1        2004.0           11.0        Apartment          49
# ..    ...       ...           ...            ...              ...         ...
# 191  1022         1        2005.0            7.0        Apartment          22
# 192  1028         1        2005.0            7.0        Apartment          28
# 193  1034         1        2005.0            7.0        Apartment          34
# 194  1037         1        2005.0            7.0        Apartment          37
# 195  1042         1        2005.0            7.0        Apartment          42
#
# ...

# %%
Sex=df['Gender'].value_counts()

# %%
Sex
# Out:
# M        108
# F         70
# firms     18
# Name: Gender, dtype: int64

# %%
# gender=["Male ","Female","Firms"]
# Number=[108,70,18]

# fig. ax = plt.subplots()
# ax.pie(Number, labels=gender, autopct="%1.1f%%" )
# ax.axis("equal")
# ax.set_title("home data")

# %%
# data = {'First Column Name':  ['First value', 'Second value',],
#         'Second Column Name': ['First value', 'Second value',]
#         }

# df = pd.DataFrame (data, columns = ['First Column Name','Second Column Name'])

# print (df)

# %%
states=df['State'].value_counts()

# %%
stateframe=pd.DataFrame({'states':states})

# %%
stateframe
# Out:
#             states
# California     119
# Nevada          17
# Colorado        11
# Oregon          11
# Arizona         11
# Utah             6
# Virginia         4
# Kansas           1
# Wyoming          1

# %%
frq=(stateframe['states']/stateframe['states'].sum())*100

# %%
frq
# Out:
# California    65.745856
# Nevada         9.392265
# Colorado       6.077348
# Oregon         6.077348
# Arizona        6.077348
# Utah           3.314917
# Virginia       2.209945
# Kansas         0.552486
# Wyoming        0.552486
# Name: states, dtype: float64

# %%
stateframe['Relative frequency'] = frq

# %%
stateframe
# Out:
#             states  Relative frequency
# California     119           65.745856
# Nevada          17            9.392265
# Colorado        11            6.077348
# Oregon          11            6.077348
# Arizona         11            6.077348
# Utah             6            3.314917
# Virginia         4            2.209945
# Kansas           1            0.552486
# Wyoming          1            0.552486

# %%
stateframe['Cumulative frequency'] = stateframe['Relative frequency'].cumsum()

# %%
stateframe
# Out:
#             states  Relative frequency  Cumulative frequency
# California     119           65.745856             65.745856
# Nevada          17            9.392265             75.138122
# Colorado        11            6.077348             81.215470
# Oregon          11            6.077348             87.292818
# Arizona         11            6.077348             93.370166
# Utah             6            3.314917             96.685083
# Virginia         4            2.209945             98.895028
# Kansas           1            0.552486             99.447514
# Wyoming          1            0.552486            100.000000

# %%
df['Country'].value_counts()
# Out:
# USA        165
# USA         12
# Canada       7
# Russia       4
# Belgium      2
# UK           2
# Germany      1
# Denmark      1
# Mexico       1
# Name: Country, dtype: int64

# %%
frqs=(stateframe['states']/)*100

# %%
frqs
# Out:
# California    67.231638
# Nevada         9.604520
# Colorado       6.214689
# Oregon         6.214689
# Arizona        6.214689
# Utah           3.389831
# Virginia       2.259887
# Kansas         0.564972
# Wyoming        0.564972
# Name: states, dtype: float64

# %%
stateframe['cumulative  frequency'] = frqs
stateframe['Cumulative USA only'] = stateframe['cumulative  frequency'].cumsum()

# %%
stateframe
# Out:
#             states  Relative frequency  Cumulative frequency  \
# California     119           65.745856             65.745856
# Nevada          17            9.392265             75.138122
# Colorado        11            6.077348             81.215470
# Oregon          11            6.077348             87.292818
# Arizona         11            6.077348             93.370166
# Utah             6            3.314917             96.685083
# Virginia         4            2.209945             98.895028
# Kansas           1            0.552486             99.447514
# Wyoming          1            0.552486            100.000000
#
#             cumulative  frequency  Cumulative USA only
# California              67.231638            67.231638
# Nevada                   9.604520            76.836158
# Colorado                 6.214689            83.050847
# Oregon                   6.214689            89.265537
# Arizona                  6.214689            95.480226
# ...
